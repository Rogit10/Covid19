# %%
import pandas as pd

#reading the data
car = pd.read_csv('/content/car-resale_prediction.csv')

#Inspect the data
car.head()
# Out:
#                                             Car_Name        Make       Model  \
# 0   Volkswagen Ameo [2016-2017] Highline 1.5L AT (D)  Volkswagen        Ameo
# 1              Hyundai i20 Active [2015-2020] 1.2 SX     Hyundai  i20 Active
# 2                               Honda WR-V VX i-VTEC       Honda        WR-V
# 3                           Renault Kwid 1.0 RXT AMT     Renault        Kwid
# 4  Hyundai Grand i10 [2017-2020] Asta 1.2 Kappa VTVT     Hyundai   Grand i10
#
#    Make_Year   Color  Body_Type Mileage_Run No_of_Owners  Seating_Capacity  \
# 0       2017  silver      sedan      44,611          1st                 5
# 1       2016     red  crossover      20,305          1st                 5
# 2       2019   white        suv      29,540          2nd                 5
# 3       2017  bronze  hatchback      35,680          1st                 5
# 4       2017  orange  hatchback      25,126          1st                 5
#
# ...

# %%
#Identifying Null values
sumofnull = car.isnull().sum()

#Inspect the data
sumofnull
# Out:
# Car_Name                 0
# Make                     0
# Model                    0
# Make_Year                0
# Color                    0
# Body_Type                0
# Mileage_Run              0
# No_of_Owners             0
# Seating_Capacity         0
# Fuel_Type                0
# Fuel_Tank_Capacity(L)    0
# Engine_Type              0
# CC_Displacement          0
# Transmission             0
# Transmission_Type        0
# Power(BHP)               0
# Torque(Nm)               0
# Mileage(kmpl)            0
# Emission                 0
# Price                    0
# dtype: int64

# %%
#Identifying dupilcates
duplicated = car.duplicated().sum()

#Inspect the data
duplicated
# Out:
# 62

# %%
#Dropping duplicates
car.drop_duplicates(inplace = True)

#Inspect the data
duplicated = car.duplicated().sum()

# %%
#Dropping columns
car.drop(columns = ['Car_Name', 'Engine_Type', 'CC_Displacement','Power(BHP)','Torque(Nm)','Fuel_Tank_Capacity(L)','Transmission','Color','Body_Type'],inplace = True)

car.head()
# Out:
#          Make       Model  Make_Year Mileage_Run No_of_Owners  \
# 0  Volkswagen        Ameo       2017      44,611          1st
# 1     Hyundai  i20 Active       2016      20,305          1st
# 2       Honda        WR-V       2019      29,540          2nd
# 3     Renault        Kwid       2017      35,680          1st
# 4     Hyundai   Grand i10       2017      25,126          1st
#
#    Seating_Capacity Fuel_Type Transmission_Type Mileage(kmpl) Emission  \
# 0                 5    diesel         Automatic         21.66    BS IV
# 1                 5    petrol            Manual         17.19     BS V
# 2                 5    petrol            Manual          16.5    BS IV
# 3                 5    petrol            Manual          21.7    BS IV
# 4                 5    petrol            Manual          18.9     BS V
#
#       Price
# 0  6,57,000
# 1  6,82,000
# 2  7,93,000
# 3  4,14,000
# 4  5,15,000

# %%
#Finding data_types
data_types = car.dtypes
data_types
# Out:
# Make                 object
# Model                object
# Make_Year             int64
# Mileage_Run          object
# No_of_Owners         object
# Seating_Capacity      int64
# Fuel_Type            object
# Transmission_Type    object
# Mileage(kmpl)        object
# Emission             object
# Price                object
# dtype: object

# %%
#Cleaning price column
car['Price'] = car['Price'].str.replace(',', '')

#inspect the data
car.head()
# Out:
#          Make       Model  Make_Year Mileage_Run No_of_Owners  \
# 0  Volkswagen        Ameo       2017      44,611          1st
# 1     Hyundai  i20 Active       2016      20,305          1st
# 2       Honda        WR-V       2019      29,540          2nd
# 3     Renault        Kwid       2017      35,680          1st
# 4     Hyundai   Grand i10       2017      25,126          1st
#
#    Seating_Capacity Fuel_Type Transmission_Type Mileage(kmpl) Emission   Price
# 0                 5    diesel         Automatic         21.66    BS IV  657000
# 1                 5    petrol            Manual         17.19     BS V  682000
# 2                 5    petrol            Manual          16.5    BS IV  793000
# 3                 5    petrol            Manual          21.7    BS IV  414000
# 4                 5    petrol            Manual          18.9     BS V  515000

# %%
#Cleaning Mileage_run column
car['Mileage_Run'] = car['Mileage_Run'].str.replace(',','')

#insoect the data
car.head()
# Out:
#          Make       Model  Make_Year Mileage_Run No_of_Owners  \
# 0  Volkswagen        Ameo       2017       44611          1st
# 1     Hyundai  i20 Active       2016       20305          1st
# 2       Honda        WR-V       2019       29540          2nd
# 3     Renault        Kwid       2017       35680          1st
# 4     Hyundai   Grand i10       2017       25126          1st
#
#    Seating_Capacity Fuel_Type Transmission_Type Mileage(kmpl) Emission   Price
# 0                 5    diesel         Automatic         21.66    BS IV  657000
# 1                 5    petrol            Manual         17.19     BS V  682000
# 2                 5    petrol            Manual          16.5    BS IV  793000
# 3                 5    petrol            Manual          21.7    BS IV  414000
# 4                 5    petrol            Manual          18.9     BS V  515000

# %%
#Renaming column
car.rename(columns={'Make': 'Company'}, inplace=True)

#inspect the data
car.head()
# Out:
#       Company       Model  Make_Year Mileage_Run No_of_Owners  \
# 0  Volkswagen        Ameo       2017       44611          1st
# 1     Hyundai  i20 Active       2016       20305          1st
# 2       Honda        WR-V       2019       29540          2nd
# 3     Renault        Kwid       2017       35680          1st
# 4     Hyundai   Grand i10       2017       25126          1st
#
#    Seating_Capacity Fuel_Type Transmission_Type Mileage(kmpl) Emission   Price
# 0                 5    diesel         Automatic         21.66    BS IV  657000
# 1                 5    petrol            Manual         17.19     BS V  682000
# 2                 5    petrol            Manual          16.5    BS IV  793000
# 3                 5    petrol            Manual          21.7    BS IV  414000
# 4                 5    petrol            Manual          18.9     BS V  515000

# %%
#Encoding categorical features

from sklearn.preprocessing import LabelEncoder

lab_encode = LabelEncoder()
for columns in ['No_of_Owners','Fuel_Type','Emission','Transmission_Type']:
    car[columns] = lab_encode.fit_transform(car[columns])


#--- Inspect data ---
car.head()

#Inserted label values for reference
#Noofowners = 0,1,2
#Fuel_type = 0,1,2 {D,P,CNG}
#Transmissiontype = 0,1 {A,M}
#Emmission = 0,1,2 {BS3,BS4,BS5}
# Out:
#       Company       Model  Make_Year Mileage_Run  No_of_Owners  \
# 0  Volkswagen        Ameo       2017       44611             0
# 1     Hyundai  i20 Active       2016       20305             0
# 2       Honda        WR-V       2019       29540             1
# 3     Renault        Kwid       2017       35680             0
# 4     Hyundai   Grand i10       2017       25126             0
#
#    Seating_Capacity  Fuel_Type  Transmission_Type Mileage(kmpl)  Emission  \
# 0                 5          0                  0         21.66         1
# 1                 5          1                  1         17.19         2
# 2                 5          1                  1          16.5         1
# 3                 5          1                  1          21.7         1
# 4                 5          1                  1          18.9         2
#
#     Price
# 0  657000
# 1  682000
# 2  793000
# 3  414000
# 4  515000

# %%
data_types1 = car.dtypes
data_types1
# Out:
# Company              object
# Model                object
# Make_Year             int64
# Mileage_Run          object
# No_of_Owners          int64
# Seating_Capacity      int64
# Fuel_Type             int64
# Transmission_Type     int64
# Mileage(kmpl)        object
# Emission              int64
# Price                object
# dtype: object

# %%
car['Mileage(kmpl)'] = car['Mileage(kmpl)'].round()
car.head()
# Out:
#       Company       Model  Make_Year  Mileage_Run  No_of_Owners  \
# 0  Volkswagen        Ameo       2017        44611             0
# 1     Hyundai  i20 Active       2016        20305             0
# 2       Honda        WR-V       2019        29540             1
# 3     Renault        Kwid       2017        35680             0
# 4     Hyundai   Grand i10       2017        25126             0
#
#    Seating_Capacity  Fuel_Type  Transmission_Type  Mileage(kmpl)  Emission  \
# 0                 5          0                  0           22.0         1
# 1                 5          1                  1           17.0         2
# 2                 5          1                  1           16.0         1
# 3                 5          1                  1           22.0         1
# 4                 5          1                  1           19.0         2
#
#     Price
# 0  657000
# 1  682000
# 2  793000
# 3  414000
# 4  515000

# %%
# Replace NaN values with a specific value (e.g., 0)
car['Mileage(kmpl)'].fillna(0, inplace=True)

# Convert to integers
car['Mileage(kmpl)'] = car['Mileage(kmpl)'].astype(int)
# Out:
# Company              object
# Model                object
# Make_Year             int64
# Mileage_Run           int64
# No_of_Owners          int64
# Seating_Capacity      int64
# Fuel_Type             int64
# Transmission_Type     int64
# Mileage(kmpl)         int64
# Emission              int64
# Price                 int64
# dtype: object

# %%
# Assuming 'car' is your DataFrame
object_columns = ['Mileage_Run', 'Mileage(kmpl)', 'Price']

# Convert specific columns to numeric
car[object_columns] = car[object_columns].apply(pd.to_numeric, errors='coerce')

# inspect the DataFrame
dataTypes2 = car.dtypes
dataTypes2
# Out:
# Company              object
# Model                object
# Make_Year             int64
# Mileage_Run           int64
# No_of_Owners          int64
# Seating_Capacity      int64
# Fuel_Type             int64
# Transmission_Type     int64
# Mileage(kmpl)         int64
# Emission              int64
# Price                 int64
# dtype: object

# %%
#Building the Machine learning models
from sklearn.model_selection import train_test_split

x = car.drop('Price',axis=1)
Y = car['Price']

x_train, x_test, y_train, y_test = train_test_split(x, Y, test_size=0.2, random_state=4)

# %%
# from sklearn.preprocessing import OneHotEncoder
# from sklearn.compose import make_column_transformer

# # Specify categorical columns
# categorical_columns = ['Model', 'Company']

# # Instantiate OneHotEncoder
# ohe = OneHotEncoder()

# # Fit OneHotEncoder on the categorical columns in 'x'
# ohe.fit(x[categorical_columns])

# # Create a column transformer using make_column_transformer
# column_trans = make_column_transformer(
#     (ohe, categorical_columns),
#     remainder='passthrough'
# )

# # Fit and transform 'x' using the column transformer
# x_transformed = column_trans.fit_transform(x)

# # Display the transformed 'x'
# print(x_transformed)
# Out:
#   (0, 6)	1.0
#   (0, 102)	1.0
#   (0, 103)	2017.0
#   (0, 104)	44611.0
#   (0, 106)	5.0
#   (0, 109)	22.0
#   (0, 110)	1.0
#   (1, 86)	1.0
#   (1, 91)	1.0
#   (1, 103)	2016.0
#   (1, 104)	20305.0
#   (1, 106)	5.0
#   (1, 107)	1.0
#   (1, 108)	1.0
#   (1, 109)	17.0
#   (1, 110)	2.0
#   (2, 76)	1.0
#   (2, 90)	1.0
#   (2, 103)	2019.0
#   (2, 104)	29540.0
#   (2, 105)	1.0
#   (2, 106)	5.0
#   (2, 107)	1.0
#   (2, 108)	1.0
#   (2, 109)	16.0
#   :	:
#   (910, 109)	17.0
#   (910, 110)	2.0
#   (911, 73)	1.0
#   (911, 91)	1.0
#   (911, 103)	2014.0
#   (911, 104)	52846.0
#   (911, 106)	5.0
#   (911, 107)	1.0
#   (911, 109)	17.0
#   (912, 30)	1.0
#   (912, 89)	1.0
#   (912, 103)	2020.0
#   (912, 104)	28335.0
#   (912, 105)	1.0
#   (912, 106)	5.0
#   (912, 109)	18.0
#   (912, 110)	2.0
#   (913, 38)	1.0
#   (913, 96)	1.0
#   (913, 103)	2018.0
#   (913, 104)	41176.0
#   (913, 106)	5.0
#   (913, 107)	1.0
#   (913, 109)	21.0
#   (913, 110)	2.0
